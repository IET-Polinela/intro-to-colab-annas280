# %%
from google.colab import auth
auth.authenticate_user()

# Konfigurasi identitas GitHub
# !git config --global user.email "annasadit45@gmail.com"
# !git config --global user.name "annas280"

# Gunakan akses token yang disimpan sebagai secret (lebih aman daripada hardcoding)
access_token = "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"
repo_owner = "IET-Polinela"
repo_name = "intro-to-colab-annas280"

# Cloning repository
# !git clone https://{access_token}@github.com/{repo_owner}/{repo_name}.git

# Masuk ke direktori repository
# %cd {repo_name}
# Out:
# Cloning into 'intro-to-colab-annas280'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 12 (delta 0), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 72.33 KiB | 3.29 MiB/s, done.
# /content/intro-to-colab-annas280

# %%
# !python iris_knn.py
# Out:
# Accuracy: 1.00
# Figure(600x400)

# %%
# !git add .
# !git commit -m “iris_knn.py”
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !python mnist_cnn.py
# Out:
# 2025-03-03 16:17:35.780649: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741018655.800038    7712 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741018655.806159    7712 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 16:17:35.826554: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !git add .
# !git commit -m “mnist_cnn.py”
# !git push origin main
# Out:
# [main 37ef710] “mnist_cnn.py”
#  3 files changed, 65 insertions(+)
#  create mode 100644 evaluation.txt
#  create mode 100644 mnist_cnn.py
#  create mode 100644 training_performance.png
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 52.07 KiB | 17.36 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/IET-Polinela/intro-to-colab-annas280.git
#    f91a761..37ef710  main -> main

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %%writefile iris_knn.py
# Out:
# Overwriting iris_knn.py

# %%
# %%writefile mnist_cnn.py.py
# Out:
# Writing mnist_cnn.py.py

# %%
# !cp "/content/drive/Drive Saya/Lab1_23758034.ipynb" "/content/[intro-to-colab-annas280]/"
# Out:
# cp: cannot stat '/content/drive/Drive Saya/Lab1_23758034.ipynb': No such file or directory
